# %%
import pandas as pd
import re

# %%
gold = pd.read_csv('koyfin_20201107_xauusd_price.csv')

# %% [markdown]
# ## Data Cleaning

# %%
gold
# Out:
#              Date XAUUSD Open XAUUSD Low XAUUSD High XAUUSD Close  \
# 0      11-06-2020   1,949.53   1,936.82    1,960.31     1,952.11
# 1      11-05-2020   1,903.10   1,902.89    1,952.50     1,950.56
# 2      11-04-2020   1,909.59   1,886.90    1,915.16     1,901.86
# 3      11-03-2020   1,895.16   1,888.89    1,910.40     1,906.91
# 4      11-02-2020   1,881.51   1,874.37    1,895.50     1,895.50
# ...           ...         ...        ...         ...          ...
# 11848  05-29-1970    35.9500    35.9500     35.9500      35.9500
# 11849  04-30-1970    35.6200    35.6200     35.6200      35.6200
# 11850  03-31-1970    35.0900    35.0900     35.0900      35.0900
# 11851  02-27-1970    34.9900    34.9900     34.9900      34.9900
# 11852  02-26-1970    34.9400    34.9400     34.9400      34.9400
#
#       XAUUSD Adj. Close  XAUUSD Volume  XAUUSD Vol  (1M)  XAUUSD Vol  (3M)  \
# 0             1,952.11               0             15.76             17.28
# 1             1,950.56               0             15.77             20.87
# 2             1,901.86               0             13.31             20.19
# 3             1,906.91               0             14.92             20.38
# 4             1,895.50               0             14.97             20.50
# ...                 ...            ...               ...               ...
# 11848          35.9500               0               NaN               NaN
# 11849          35.6200               0               NaN               NaN
# 11850          35.0900               0               NaN               NaN
# 11851          34.9900               0               NaN               NaN
# 11852          34.9400               0               NaN               NaN
#
#        XAUUSD Vol  (6M)
# 0                 17.39
# 1                 17.43
# 2                 17.10
# 3                 17.10
# 4                 17.09
# ...                 ...
# 11848               NaN
# 11849               NaN
# 11850               NaN
# 11851               NaN
# 11852               NaN
#
# [11853 rows x 10 columns]

# %%
# removing end space
gold['XAUUSD Open'] = [re.sub(' ', '', ele) for ele in gold['XAUUSD Open']]
gold['XAUUSD Low'] = [re.sub(' ', '', ele) for ele in gold['XAUUSD Low']]
gold['XAUUSD High']= [re.sub(' ', '', ele) for ele in gold['XAUUSD High']]
gold['XAUUSD Close'] =[re.sub(' ', '', ele) for ele in gold['XAUUSD Close']]
gold['XAUUSD Adj. Close'] =[re.sub(' ', '', ele) for ele in gold['XAUUSD Adj. Close']]

# removing comas
gold['XAUUSD Open'] = [re.sub(',','', ele) for ele in gold['XAUUSD Open']]
gold['XAUUSD Low'] = [re.sub(',','', ele) for ele in gold['XAUUSD Low']]
gold['XAUUSD High']= [re.sub(',','', ele) for ele in gold['XAUUSD High']]
gold['XAUUSD Close'] =[re.sub(',','', ele) for ele in gold['XAUUSD Close']]
gold['XAUUSD Adj. Close'] =[re.sub(',','', ele) for ele in gold['XAUUSD Adj. Close']]

# %%
# Changing dtypes for price and dates and replacing ' Date' by 'Date' as name of the column
gold[['XAUUSD Open', 'XAUUSD Low', 'XAUUSD High', 'XAUUSD Close', 'XAUUSD Adj. Close']] = gold[['XAUUSD Open', 'XAUUSD Low', 'XAUUSD High', 'XAUUSD Close', 'XAUUSD Adj. Close']].astype(float)
gold
# Out:
#              Date  XAUUSD Open  XAUUSD Low  XAUUSD High  XAUUSD Close  \
# 0      11-06-2020      1949.53     1936.82      1960.31       1952.11
# 1      11-05-2020      1903.10     1902.89      1952.50       1950.56
# 2      11-04-2020      1909.59     1886.90      1915.16       1901.86
# 3      11-03-2020      1895.16     1888.89      1910.40       1906.91
# 4      11-02-2020      1881.51     1874.37      1895.50       1895.50
# ...           ...          ...         ...          ...           ...
# 11848  05-29-1970        35.95       35.95        35.95         35.95
# 11849  04-30-1970        35.62       35.62        35.62         35.62
# 11850  03-31-1970        35.09       35.09        35.09         35.09
# 11851  02-27-1970        34.99       34.99        34.99         34.99
# 11852  02-26-1970        34.94       34.94        34.94         34.94
#
#        XAUUSD Adj. Close  XAUUSD Volume  XAUUSD Vol  (1M)  XAUUSD Vol  (3M)  \
# 0                1952.11              0             15.76             17.28
# 1                1950.56              0             15.77             20.87
# 2                1901.86              0             13.31             20.19
# 3                1906.91              0             14.92             20.38
# 4                1895.50              0             14.97             20.50
# ...                  ...            ...               ...               ...
# 11848              35.95              0               NaN               NaN
# 11849              35.62              0               NaN               NaN
# 11850              35.09              0               NaN               NaN
# 11851              34.99              0               NaN               NaN
# 11852              34.94              0               NaN               NaN
#
#        XAUUSD Vol  (6M)
# 0                 17.39
# 1                 17.43
# 2                 17.10
# 3                 17.10
# 4                 17.09
# ...                 ...
# 11848               NaN
# 11849               NaN
# 11850               NaN
# 11851               NaN
# 11852               NaN
#
# [11853 rows x 10 columns]

# %%
gold['Date'] = pd.to_datetime(gold[' Date'])
gold.index = gold.Date 
gold.drop(columns = ['Date', ' Date'])
# Out:
#             XAUUSD Open  XAUUSD Low  XAUUSD High  XAUUSD Close  \
# Date
# 2020-11-06      1949.53     1936.82      1960.31       1952.11
# 2020-11-05      1903.10     1902.89      1952.50       1950.56
# 2020-11-04      1909.59     1886.90      1915.16       1901.86
# 2020-11-03      1895.16     1888.89      1910.40       1906.91
# 2020-11-02      1881.51     1874.37      1895.50       1895.50
# ...                 ...         ...          ...           ...
# 1970-05-29        35.95       35.95        35.95         35.95
# 1970-04-30        35.62       35.62        35.62         35.62
# 1970-03-31        35.09       35.09        35.09         35.09
# 1970-02-27        34.99       34.99        34.99         34.99
# 1970-02-26        34.94       34.94        34.94         34.94
#
#             XAUUSD Adj. Close  XAUUSD Volume  XAUUSD Vol  (1M)  \
# Date
# 2020-11-06            1952.11              0             15.76
# 2020-11-05            1950.56              0             15.77
# 2020-11-04            1901.86              0             13.31
# 2020-11-03            1906.91              0             14.92
# 2020-11-02            1895.50              0             14.97
# ...                       ...            ...               ...
# 1970-05-29              35.95              0               NaN
# 1970-04-30              35.62              0               NaN
# 1970-03-31              35.09              0               NaN
# 1970-02-27              34.99              0               NaN
# 1970-02-26              34.94              0               NaN
#
#             XAUUSD Vol  (3M)  XAUUSD Vol  (6M)
# Date
# 2020-11-06             17.28             17.39
# 2020-11-05             20.87             17.43
# 2020-11-04             20.19             17.10
# 2020-11-03             20.38             17.10
# 2020-11-02             20.50             17.09
# ...                      ...               ...
# 1970-05-29               NaN               NaN
# 1970-04-30               NaN               NaN
# 1970-03-31               NaN               NaN
# 1970-02-27               NaN               NaN
# 1970-02-26               NaN               NaN
#
# [11853 rows x 9 columns]

# %%
gold.to_csv('C_20201107_xauusd_price.csv')
