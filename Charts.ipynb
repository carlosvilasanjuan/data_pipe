# %%
import pandas as pd
import seaborn as sns

# %%
gold = pd.read_csv('E_20201109_xauusd_price.csv')

# %%
gold['date'] = pd.to_datetime(gold['date'])

# %%
gold['XAUM1 Close'] = gold['XAUUSD Close']/ gold['M1 USD (B)']
gold
# Out:
#       Unnamed: 0       date  XAUUSD Open  XAUUSD Low  XAUUSD High  \
# 0              0 2020-10-26      1901.89     1893.69      1907.17
# 1              1 2020-10-19      1898.90     1898.31      1916.62
# 2              2 2020-10-12      1930.30     1919.59      1932.30
# 3              3 2020-10-05      1899.29     1888.24      1916.90
# 4              4 2020-09-28      1861.55     1850.80      1882.87
# ...          ...        ...          ...         ...          ...
# 2013        2013 1980-12-01       635.00      635.00       635.00
# 2014        2014 1980-11-24       631.00      631.00       631.00
# 2015        2015 1980-11-17       611.75      611.75       611.75
# 2016        2016 1980-11-10       612.50      612.50       612.50
# 2017        2017 1980-11-03       640.50      640.50       640.50
#
#       XAUUSD Close  XAUUSD Adj. Close  XAUUSD Vol  (1M)  XAUUSD Vol  (3M)  \
# 0          1901.40            1901.40             14.64             20.82
# 1          1903.30            1903.30             17.26             21.28
# 2          1922.92            1922.92             16.65             21.44
# 3          1913.83            1913.83             13.78             20.74
# 4          1881.93            1881.93             13.26             20.58
# ...            ...                ...               ...               ...
# 2013        635.00             635.00             34.45             30.41
# 2014        631.00             631.00             33.83             29.81
# 2015        611.75             611.75             36.05             30.12
# 2016        612.50             612.50             33.19             29.69
# 2017        640.50             640.50             24.88             26.46
#
#       XAUUSD Vol  (6M)  M1 USD (B)  M2 USD (B)  XAUM1 Close
# 0                17.14      5580.6     18838.6     0.340716
# 1                17.25      5545.7     18815.3     0.343203
# 2                17.33      5603.9     18795.6     0.343140
# 3                17.37      5507.7     18689.1     0.347483
# 4                17.88      5500.2     18643.3     0.342157
# ...                ...         ...         ...          ...
# 2013             29.98       410.5      1596.1     1.546894
# 2014             31.08       410.8      1597.2     1.536027
# 2015             31.50       411.3      1596.3     1.487357
# 2016             31.05       410.4      1592.9     1.492446
# 2017             29.56       409.2      1591.4     1.565249
#
# [2018 rows x 13 columns]

# %%
sns.lineplot(data=gold, x='date', y='XAUUSD Close')
# Out:
# <AxesSubplot:xlabel='date', ylabel='XAUUSD Close'>

# %%
sns.lineplot(data=gold, x='date', y='XAUUSD Close')
sns.lineplot(data=gold, x='date', y='M1 USD (B)')
# Out:
# <AxesSubplot:xlabel='date', ylabel='XAUUSD Close'>

# %%
'1990-01-01','2020-10-10'ax = gold.plot(x='date', y = 'XAUUSD Close')
sns.linepl
ot(data=gold, x='date', y='XAUUSD Close')
sns.lineplot(data=gold, x='date', y='M1 USD (B)')
sns.lineplot(data=gold, x='date', y='M2 USD (B)')
# Out:
# <AxesSubplot:xlabel='date', ylabel='XAUUSD Close'>

# %%
sns.lineplot(data=gold, x='date', y='XAUM1 Close')
# Out:
# <AxesSubplot:xlabel='date', ylabel='XAUM1 Close'>

# %%
sns.lineplot(data=gold, x='date', y='XAUM1 Close')
ax.set_yscale=("log")
